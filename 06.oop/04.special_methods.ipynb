# %%
#allow us to use built in functions with user created objects

# %%
#called dunder or magic methods also

# %%
mylist=[1,2,3]

# %%
print(mylist)
# Out:
# [1, 2, 3]

# %%
class Sample():
    pass

mysample=Sample()

# %%
print(mysample)
# Out:
# <__main__.Sample object at 0x000001FF87616940>

# %%
class Book():
    def __init__(self,title,author,pages):
        self.title=title
        self.author=author
        self.pages=pages
    
    def __str__(self):
        return f"{self.title} by {self.author}"
    
    def __len__(self):
        return self.pages

# %%
b=Book("book", "jack", 200)

# %%
print(b)
# Out:
# book by jack

# %%
str(b)
# Out:
# 'book by jack'

# %%
len(b)
# Out:
# 200

# %%
#deleting book
del b

# %%
b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22348/1685013873.py in <module>
# ----> 1 b
#
# NameError: name 'b' is not defined

# %%
class Book():
    def __init__(self,title,author,pages):
        self.title=title
        self.author=author
        self.pages=pages
    
    def __str__(self):
        return f"{self.title} by {self.author}"
    
    def __len__(self):
        return self.pages
    
    def __del__(self):
        print("book deleted...")
        

b=Book("book", "jack", 200)

# %%
del(b)
# Out:
# book deleted...
