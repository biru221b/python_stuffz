# %%
print([1,2,3])
print([1,2,3])
print([1,2,3])
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]

# %%
def display(row1,row2,row3):
    print(row1)
    print(row2)
    print(row3)

# %%
row=[1,2,3]
display(row,row,row)
# Out:
# [1, 2, 3]
# [1, 2, 3]
# [1, 2, 3]

# %% [markdown]
# 1. display some visual
# 2. let user update through interaction
# 3. update variables
# 4. display updated visual

# %%
row1=[' ', ' ',' ']
row2=[' ', 'X',' ']
row3=[' ', ' ',' ']
display(row1,row2,row3)
# Out:
# [' ', ' ', ' ']
# [' ', 'X', ' ']
# [' ', ' ', ' ']

# %% [markdown]
# #displaying information

# %%
input("please enter a value:")
# Out:
# please enter a value:x
# 'x'

# %%
result=input("please enter a value:")
# Out:
# please enter a value:2

# %%
type(result)
# Out:
# str

# %%
result_int= int(result)

# %%
type(result)
# Out:
# str

# %%
type(result_int)
# Out:
# int

# %%
position_index=input("choose index:")
# Out:
# choose index:1

# %%
#but
row1[position_index]
#won't work because type of position_index is str
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21636/2742398846.py in <module>
#       1 #but
# ----> 2 row1[position_index]
#       3 #won't work because type of position_index is str
#
# TypeError: list indices must be integers or slices, not str

# %%
row1[int(position_index)]
# Out:
# ' '

# %%
#or
position_index=int(input("choose index:"))
row1[int(position_index)]
# Out:
# choose index:2
# ' '

# %% [markdown]
# # kernel will wait for input function before running other proceeding command lines

# %%
input("")

# %%
2+2

# %% [markdown]
# #here if we dont enter value for input, 2+2 wo'nt run, also don't run input twice

# %%
#checking valid data type while taking input

# %%
def user_choice():
    choice= input("input number (0-10):")
    return int(choice)

# %%
user_choice()
# Out:
# input number (0-10):11
# 11

# %%
user_choice()
# Out:
# input number (0-10):nine
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5984/2296594588.py in <module>
# ----> 1 user_choice()
#
# ~\AppData\Local\Temp/ipykernel_5984/3558052638.py in user_choice()
#       1 def user_choice():
#       2     choice= input("input number (0-10):")
# ----> 3     return int(choice)
#
# ValueError: invalid literal for int() with base 10: 'nine'
