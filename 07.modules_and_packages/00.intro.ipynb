# %%
#libraries like django, flask, matplotlib, sikit-learn, pandas, etc

# %%
#Python libraries are collections of pre-written code (modules and packages) that provide reusable functions, classes, and methods to perform common tasks

# %% [markdown]
# 1.Install it using pip in your terminal (e.g., pip install pandas)
#
# 2. Import it into your Python program using the import statement (e.g., import pandas as pd).

# %%
#can simply execute in cmd by installing, and calling python and executing

# %%
#modules are .py scripts that we can run in another .py script, while packages are collections of modules organized in directories with __init__.py files
